# %% [markdown]
# # Coursera Capstone Project
# ## Choosing the ideal location to open a Chinese Restaurant in Chicago

# %%
import random # library for random number generation
import numpy as np # library for vectorized computation
import pandas as pd # library to process data as dataframes

import matplotlib.pyplot as plt # plotting library
# backend for rendering plots within the browser
# %matplotlib inline 

from sklearn.cluster import KMeans 
from sklearn.datasets.samples_generator import make_blobs

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ### 1.Scrape the Wikipedia page for neighborhood information

# %%
# import the library we use to open URLs
import urllib.request

# specify which URL/web page we are going to be scraping
url = "https://en.wikipedia.org/wiki/Community_areas_in_Chicago"
# open the url using urllib.request and put the HTML into the page variable
page = urllib.request.urlopen(url)

# %% [markdown]
# ### Using BeautifulSoup package to scrape the table

# %%
# import the BeautifulSoup library so we can parse HTML and XML documents
from bs4 import BeautifulSoup
import requests
# send the GET request
data = requests.get("https://en.wikipedia.org/wiki/Category:Community_areas_of_Chicago").text
soup = BeautifulSoup(data, 'html.parser')

# create a list to store neighborhood data
neigh = []

# %% [markdown]
# ### Get the dataframe of 78 community areas in Chicago

# %%
right_table=soup.find_all('div', class_='mw-category')[0].findAll('li')

for row in right_table:
    neigh.append(row.text)

neigh = neigh[4:]
    
df = pd.DataFrame({'Neighborhood': neigh})
df['Neighborhood'] = df.Neighborhood.str.replace(', Chicago','', regex=True)
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#      Neighborhood
# 0     Albany Park
# 1  Archer Heights
# 2   Armour Square
# 3         Ashburn
# 4  Auburn Gresham

# %%
# print the number of rows of the dataframe
df.head()
# Out:
#      Neighborhood
# 0     Albany Park
# 1  Archer Heights
# 2   Armour Square
# 3         Ashburn
# 4  Auburn Gresham

# %% [markdown]
# ### 2.Get the geographical coordinates of the community areas

# %% [markdown]
# Import relevant libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %%
import geocoder
# define a function to get coordinates
def get_coor(neighborhood):
    # initialize your variable to None
    lat_long_coords = None
    # loop until you get the coordinates
    while(lat_long_coords is None):
        g = geocoder.arcgis('{},IL,USA'.format(neighborhood))
        lat_long_coords = g.latlng
    return lat_long_coords

# %%
coords = [ get_coor(nei) for nei in df['Neighborhood'].tolist() ]

# %%
df_coor = pd.DataFrame(coords, columns=['Latitude', 'Longitude'])
df['Latitude'] = df_coor['Latitude']
df['Longitude'] = df_coor['Longitude']
df[15:]
# Out:
#           Neighborhood  Latitude  Longitude
# 15        Chicago Lawn  41.77543  -87.69634
# 16            Clearing  41.77809  -87.75978
# 17             Douglas  38.42458  -89.98259
# 18             Dunning  41.95274  -87.79651
# 19  East Garfield Park  41.87863  -87.70514
# ..                 ...       ...        ...
# 73           West Lawn  41.77315  -87.72445
# 74        West Pullman  41.67951  -87.64189
# 75          West Ridge  41.99975  -87.69284
# 76           West Town  41.89329  -87.65743
# 77            Woodlawn  38.33304  -89.03491
#
# [63 rows x 3 columns]

# %%
address = 'Albany Park Chicago'

lat = df.loc[0,'Latitude']
long = df.loc[0,'Longitude']

# %%
# create map of Chicago neighborhoods using latitude and longitude values
map_chicago = folium.Map(location=[lat,long], zoom_start=10)

# add markers to map
for lat, lng, neighborhood in zip(df['Latitude'], df['Longitude'], 
                                           df['Neighborhood']):
    label = '{}'.format(neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_chicago)  
    
map_chicago
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# save the map as HTML file
map_chicago.save('map_chicago.html')

# %% [markdown]
# ### 3. Use the Foursquare API to explore the neighborhoods

# %%
CLIENT_ID = 'C41VKH2DGZUFOXKPMNF51ZIWFVDWXXNXPEBCP3DLJBLBRFCY' # your Foursquare ID
CLIENT_SECRET = 'WMFRFL3TVPRTKOU3ZL1ZFXYBJKGNLGE13BQUG2YJZHDSU5M0' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: C41VKH2DGZUFOXKPMNF51ZIWFVDWXXNXPEBCP3DLJBLBRFCY
# CLIENT_SECRET:WMFRFL3TVPRTKOU3ZL1ZFXYBJKGNLGE13BQUG2YJZHDSU5M0

# %% [markdown]
# ### Search for Italian restaurants around Chicago Loop

# %%
address = 'Chicago Loop, Chicago, IL, USA'

latitude = 41.8837
longitude = -87.628858
print(latitude, longitude)
# Out:
# 41.8837 -87.628858

# %%
search_query = 'Chinese Restaurant'
radius = 1000
print(search_query + ' .... OK!')
# Out:
# Chinese Restaurant .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=C41VKH2DGZUFOXKPMNF51ZIWFVDWXXNXPEBCP3DLJBLBRFCY&client_secret=WMFRFL3TVPRTKOU3ZL1ZFXYBJKGNLGE13BQUG2YJZHDSU5M0&ll=41.8837,-87.628858&v=20180604&query=Chinese Restaurant&radius=1000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ed073b247e0d6001b3acc70'},
#  'response': {'venues': [{'id': '4f32527d19836c91c7cc560f',
#     'name': 'Sixty-Five Chinese Restaurant',
#     'location': {'address': '201 W Madison St',
#      'lat': 41.881935,
#      'lng': -87.633851,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.881935,
#        'lng': -87.633851}],
#      'distance': 458,
#      'postalCode': '60606',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['201 W Madison St',
#       'Chicago, IL 60606',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '4b295853f964a520489d24e3',
#     'name': '65 Chinese Restaurant',
#     'location': {'address': '201 W Madison St',
#      'crossStreet': 'btwn Wells & Franklin St',
#      'lat': 41.881909201667135,
#      'lng': -87.63416494496623,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.881909201667135,
#        'lng': -87.63416494496623}],
#      'distance': 482,
#      'postalCode': '60606',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['201 W Madison St (btwn Wells & Franklin St)',
#       'Chicago, IL 60606',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '4b65c1ecf964a520c7fd2ae3',
#     'name': 'Triple 1 Chinese Restaurant',
#     'location': {'address': '177 N State St',
#      'crossStreet': 'at W. Lake St.',
#      'lat': 41.88542492566269,
#      'lng': -87.62796304037029,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.88542492566269,
#        'lng': -87.62796304037029},
#       {'label': 'entrance', 'lat': 41.885611, 'lng': -87.627721}],
#      'distance': 205,
#      'postalCode': '60601',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['177 N State St (at W. Lake St.)',
#       'Chicago, IL 60601',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '4d0a576d4abf721e2e52c85e',
#     'name': '65 Chinese Restaurant',
#     'location': {'address': '315 S LaSalle St',
#      'lat': 41.87800937208755,
#      'lng': -87.63267158022903,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.87800937208755,
#        'lng': -87.63267158022903}],
#      'distance': 707,
#      'postalCode': '60604',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['315 S LaSalle St',
#       'Chicago, IL 60604',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '531af2b7498ef3f61eba1e31',
#     'name': 'Yu Shan Chinese Restaurant',
#     'location': {'address': '17 E Ohio St',
#      'lat': 41.89225,
#      'lng': -87.627305,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.89225,
#        'lng': -87.627305},
#       {'label': 'entrance', 'lat': 41.892377, 'lng': -87.627276}],
#      'distance': 960,
#      'postalCode': '60611',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['17 E Ohio St',
#       'Chicago, IL 60611',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '4c8ffd7604a1b60cc1b1a33e',
#     'name': 'Chicago Mandarin Chinese Center',
#     'location': {'address': '17 N State St',
#      'lat': 41.882698,
#      'lng': -87.627312,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.882698,
#        'lng': -87.627312}],
#      'distance': 169,
#      'postalCode': '60602',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['17 N State St',
#       'Chicago, IL 60602',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '4bacc8d8f964a520040c3be3',
#     'name': 'Chinese Passport & Visa Office',
#     'location': {'address': '1 E Erie St',
#      'crossStreet': 'Suite 500',
#      'lat': 41.893074311989004,
#      'lng': -87.62780226532972,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.893074311989004,
#        'lng': -87.62780226532972}],
#      'distance': 1047,
#      'postalCode': '60611',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['1 E Erie St (Suite 500)',
#       'Chicago, IL 60611',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d12c951735',
#       'name': 'Embassy / Consulate',
#       'pluralName': 'Embassies / Consulates',
#       'shortName': 'Embassy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/embassy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '55dcc4cd498e1f6e4a6c09c1',
#     'name': 'Chinese Cultural Center',
#     'location': {'lat': 41.881082,
#      'lng': -87.636601,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.881082,
#        'lng': -87.636601}],
#      'distance': 704,
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['Chicago, IL', 'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a48',
#       'name': 'Language School',
#       'pluralName': 'Language Schools',
#       'shortName': 'Language School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '40b28c80f964a52037fb1ee3',
#     'name': 'Exchequer Restaurant & Pub',
#     'location': {'address': '226 S Wabash Ave',
#      'lat': 41.87881928744278,
#      'lng': -87.62598621466157,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.87881928744278,
#        'lng': -87.62598621466157}],
#      'distance': 593,
#      'postalCode': '60604',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['226 S Wabash Ave',
#       'Chicago, IL 60604',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '541230',
#      'url': 'https://www.grubhub.com/restaurant/exchequer-restaurant--pub-226-s-wabash-ave-chicago/541230?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=541230',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '4b2bedd4f964a520e6bd24e3',
#     'name': 'The Berghoff Restaurant',
#     'location': {'address': '17 W Adams St',
#      'crossStreet': 'btwn S Dearborn St & S State St',
#      'lat': 41.879334126547164,
#      'lng': -87.62836809709047,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.879334126547164,
#        'lng': -87.62836809709047}],
#      'distance': 487,
#      'postalCode': '60603',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['17 W Adams St (btwn S Dearborn St & S State St)',
#       'Chicago, IL 60603',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10d941735',
#       'name': 'German Restaurant',
#       'pluralName': 'German Restaurants',
#       'shortName': 'German',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/german_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '90487382'},
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '50ca02c7245f2d4aa8c2cbd3',
#     'name': 'Lockwood Restaurant and Bar',
#     'location': {'address': '17 E Monroe St',
#      'crossStreet': 'Palmer House Hilton',
#      'lat': 41.88026917405536,
#      'lng': -87.62685820694658,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.88026917405536,
#        'lng': -87.62685820694658}],
#      'distance': 416,
#      'postalCode': '60603',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['17 E Monroe St (Palmer House Hilton)',
#       'Chicago, IL 60603',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d157941735',
#       'name': 'New American Restaurant',
#       'pluralName': 'New American Restaurants',
#       'shortName': 'New American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '4b4cb5b8f964a52042bb26e3',
#     'name': 'Cocoro Japanese Restaurant',
#     'location': {'address': '668 N Wells St',
#      'lat': 41.894401467802304,
#      'lng': -87.6341914587838,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.894401467802304,
#        'lng': -87.6341914587838},
#       {'label': 'entrance', 'lat': 41.894341, 'lng': -87.63429}],
#      'distance': 1270,
#      'postalCode': '60654',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['668 N Wells St',
#       'Chicago, IL 60654',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '4f3251b219836c91c7cc0602',
#     'name': 'Restaurant Opportunity Center',
#     'location': {'address': '77 W Washington St',
#      'lat': 41.88323,
#      'lng': -87.630245,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.88323,
#        'lng': -87.630245},
#       {'label': 'entrance', 'lat': 41.88309, 'lng': -87.630541}],
#      'distance': 126,
#      'postalCode': '60602',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['77 W Washington St',
#       'Chicago, IL 60602',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '4a32de31f964a520aa9a1fe3',
#     'name': 'India House Restaurant',
#     'location': {'address': '59 W Grand Ave',
#      'crossStreet': 'btwn N Clark St & N Dearborn St',
#      'lat': 41.89176022942161,
#      'lng': -87.63037008341371,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.89176022942161,
#        'lng': -87.63037008341371},
#       {'label': 'entrance', 'lat': 41.891523, 'lng': -87.630503}],
#      'distance': 905,
#      'postalCode': '60654',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['59 W Grand Ave (btwn N Clark St & N Dearborn St)',
#       'Chicago, IL 60654',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '546728',
#      'url': 'https://www.grubhub.com/restaurant/india-house-restaurant-59-w-grand-ave-chicago/546728?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=546728',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '4a2d96c4f964a520d1971fe3',
#     'name': 'Indian Garden Restaurant',
#     'location': {'address': '247 E Ontario St',
#      'crossStreet': 'btwn N Fairbanks Ct & N St Clair St',
#      'lat': 41.89321169999999,
#      'lng': -87.62080999999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.89321169999999,
#        'lng': -87.62080999999999}],
#      'distance': 1251,
#      'postalCode': '60611',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['247 E Ontario St (btwn N Fairbanks Ct & N St Clair St)',
#       'Chicago, IL 60611',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '291559',
#      'url': 'https://www.grubhub.com/restaurant/the-indian-garden-247-e-ontario-st-chicago/291559?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=291559',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '4b441e06f964a520aef125e3',
#     'name': 'Yu Shan',
#     'location': {'address': '548 N Wells',
#      'crossStreet': 'Ohio',
#      'lat': 41.89224089892174,
#      'lng': -87.63427287340164,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.89224089892174,
#        'lng': -87.63427287340164},
#       {'label': 'entrance', 'lat': 41.892259, 'lng': -87.634235}],
#      'distance': 1051,
#      'postalCode': '60654',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['548 N Wells (Ohio)',
#       'Chicago, IL 60654',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '429e4c00f964a520b7241fe3',
#     'name': 'Bandera Restaurant',
#     'location': {'address': '535 N Michigan Ave',
#      'crossStreet': 'at E Grand Ave',
#      'lat': 41.89206746072284,
#      'lng': -87.6240444371099,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.89206746072284,
#        'lng': -87.6240444371099}],
#      'distance': 1013,
#      'postalCode': '60611',
#      'cc': 'US',
#      'neighborhood': 'Streeterville',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['535 N Michigan Ave (at E Grand Ave)',
#       'Chicago, IL 60611',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d157941735',
#       'name': 'New American Restaurant',
#       'pluralName': 'New American Restaurants',
#       'shortName': 'New American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '4b9ad8c5f964a520ccdb35e3',
#     'name': 'Plymouth Restaurant & Bar',
#     'location': {'address': '327 S Plymouth Ct',
#      'crossStreet': 'btwn W Jackson Blvd & W Van Buren St',
#      'lat': 41.87713751627466,
#      'lng': -87.62796900098705,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.87713751627466,
#        'lng': -87.62796900098705},
#       {'label': 'entrance', 'lat': 41.877473, 'lng': -87.628615}],
#      'distance': 734,
#      'postalCode': '60604',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['327 S Plymouth Ct (btwn W Jackson Blvd & W Van Buren St)',
#       'Chicago, IL 60604',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '5d8136d5adf8620008fd8200',
#     'name': 'Opus Restaurant & Café',
#     'location': {'address': '65 E Adams St',
#      'crossStreet': 'Wabash',
#      'lat': 41.879321000000004,
#      'lng': -87.625508,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.879321000000004,
#        'lng': -87.625508},
#       {'label': 'entrance', 'lat': 41.879426, 'lng': -87.625689}],
#      'distance': 560,
#      'postalCode': '60603',
#      'cc': 'US',
#      'neighborhood': 'The Loop',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['65 E Adams St (Wabash)',
#       'Chicago, IL 60603',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '4aa97164f964a520aa5320e3',
#     'name': 'Great Street Restaurant',
#     'location': {'address': '1 W Wacker Dr Upper',
#      'crossStreet': 'at Renaissance Hotel',
#      'lat': 41.88779628156399,
#      'lng': -87.62812671651848,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.88779628156399,
#        'lng': -87.62812671651848}],
#      'distance': 460,
#      'postalCode': '60601',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['1 W Wacker Dr Upper (at Renaissance Hotel)',
#       'Chicago, IL 60601',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '4be5ee4ed4f7c9b661282620',
#     'name': 'Seven Bar and Restaurant',
#     'location': {'address': '400 E Randolph St',
#      'crossStreet': 'at N Harbor Dr',
#      'lat': 41.884930079317876,
#      'lng': -87.6165335809713,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.884930079317876,
#        'lng': -87.6165335809713}],
#      'distance': 1030,
#      'postalCode': '60601',
#      'cc': 'US',
#      'neighborhood': 'Lakeshore East Community',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['400 E Randolph St (at N Harbor Dr)',
#       'Chicago, IL 60601',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '38051452'},
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '4e99c7cf4fc602a58ade9ec1',
#     'name': 'Radisson Blu - Filini Restaurant and Bar',
#     'location': {'address': '221 N Columbus Dr',
#      'crossStreet': 'Radisson Blu Aqua Hotel',
#      'lat': 41.886385,
#      'lng': -87.620102,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.886385,
#        'lng': -87.620102}],
#      'distance': 784,
#      'postalCode': '60601',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['221 N Columbus Dr (Radisson Blu Aqua Hotel)',
#       'Chicago, IL 60601',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '583e245deef5da6a525930f8',
#     'name': "Chen's Chinese Cuisine",
#     'location': {'lat': 41.8889,
#      'lng': -87.633039,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.8889,
#        'lng': -87.633039},
#       {'label': 'entrance', 'lat': 41.889069, 'lng': -87.632995}],
#      'distance': 674,
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['Chicago, IL', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '4a4d85a8f964a520f9ad1fe3',
#     'name': 'Chicago Curry House Indian Restaurant',
#     'location': {'address': '899 S Plymouth Ct',
#      'crossStreet': 'at W 9th St',
#      'lat': 41.870602848827794,
#      'lng': -87.62820876713214,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.870602848827794,
#        'lng': -87.62820876713214}],
#      'distance': 1458,
#      'postalCode': '60605',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['899 S Plymouth Ct (at W 9th St)',
#       'Chicago, IL 60605',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '68528',
#      'url': 'https://www.grubhub.com/restaurant/chicago-curry-house---indian--nepalese-cuisine-899-s-plymouth-ct-chicago/68528?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=68528',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '4a466be9f964a520d6a81fe3',
#     'name': 'Dao Thai Restaurant',
#     'location': {'address': '230 E Ohio St',
#      'crossStreet': 'btwn N Saint Clair St & N Fairbanks Ct',
#      'lat': 41.89266428571334,
#      'lng': -87.62144722028748,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.89266428571334,
#        'lng': -87.62144722028748}],
#      'distance': 1171,
#      'postalCode': '60611',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['230 E Ohio St (btwn N Saint Clair St & N Fairbanks Ct)',
#       'Chicago, IL 60611',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '250',
#      'url': 'https://www.grubhub.com/restaurant/dao-thai-restaurant-230-e-ohio-st-chicago/250?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=250',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '51d896fc498ea6557a53478f',
#     'name': 'Sofi Restaurant',
#     'location': {'address': '616 S Dearborn St',
#      'lat': 41.873879614620975,
#      'lng': -87.62910524547061,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.873879614620975,
#        'lng': -87.62910524547061}],
#      'distance': 1093,
#      'postalCode': '60605',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['616 S Dearborn St',
#       'Chicago, IL 60605',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1586195',
#      'url': 'https://www.grubhub.com/restaurant/sofi-restaurant-616-south-dearborn-street-chicago/1586195?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1586195',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '50353226e4b0c985f498ecc4',
#     'name': 'Gourmet Chinese',
#     'location': {'lat': 41.88121631998502,
#      'lng': -87.63123057482362,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.88121631998502,
#        'lng': -87.63123057482362}],
#      'distance': 339,
#      'postalCode': '60603',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['Chicago, IL 60603', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '4f324ddd19836c91c7ca82d3',
#     'name': 'Triple One Restaurant',
#     'location': {'address': '177 N State St',
#      'lat': 41.88549,
#      'lng': -87.627769,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.88549,
#        'lng': -87.627769}],
#      'distance': 218,
#      'postalCode': '60601',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['177 N State St',
#       'Chicago, IL 60601',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '4ba4704af964a520689d38e3',
#     'name': 'Markethouse Restaurant',
#     'location': {'address': '611 N Fairbanks Ct',
#      'crossStreet': 'btwn Ohio St. & Ontario St.',
#      'lat': 41.89281476221689,
#      'lng': -87.6201351640905,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.89281476221689,
#        'lng': -87.6201351640905}],
#      'distance': 1245,
#      'postalCode': '60611',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['611 N Fairbanks Ct (btwn Ohio St. & Ontario St.)',
#       'Chicago, IL 60611',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590719501',
#     'hasPerk': False},
#    {'id': '4aa986ccf964a520115420e3',
#     'name': 'Italian Village',
#     'location': {'address': '71 W Monroe St',
#      'crossStreet': 'btwn Dearborn St & Clark St',
#      'lat': 41.88092612690439,
#      'lng': -87.63024961104458,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.88092612690439,
#        'lng': -87.63024961104458},
#       {'label': 'entrance', 'lat': 41.880613, 'lng': -87.630122}],
#      'distance': 329,
#      'postalCode': '60603',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['71 W Monroe St (btwn Dearborn St & Clark St)',
#       'Chicago, IL 60603',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '262899',
#      'url': 'https://www.grubhub.com/restaurant/italian-village-restaurants-71-w-monroe-st-chicago/262899?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=262899',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '133758699'},
#     'referralId': 'v-1590719501',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                           name  \
# 0  4f32527d19836c91c7cc560f  Sixty-Five Chinese Restaurant
# 1  4b295853f964a520489d24e3          65 Chinese Restaurant
# 2  4b65c1ecf964a520c7fd2ae3    Triple 1 Chinese Restaurant
# 3  4d0a576d4abf721e2e52c85e          65 Chinese Restaurant
# 4  531af2b7498ef3f61eba1e31     Yu Shan Chinese Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1590719501    False
# 1  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1590719501    False
# 2  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1590719501    False
# 3  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1590719501    False
# 4  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1590719501    False
#
#    location.address  location.lat  location.lng  \
# 0  201 W Madison St     41.881935    -87.633851
# 1  201 W Madison St     41.881909    -87.634165
# 2    177 N State St     41.885425    -87.627963
# 3  315 S LaSalle St     41.878009    -87.632672
# 4      17 E Ohio St     41.892250    -87.627305
#
#                              location.labeledLatLngs  location.distance  ...  \
# 0  [{'label': 'display', 'lat': 41.881935, 'lng':...                458  ...
# 1  [{'label': 'display', 'lat': 41.88190920166713...                482  ...
# 2  [{'label': 'display', 'lat': 41.88542492566269...                205  ...
# 3  [{'label': 'display', 'lat': 41.87800937208755...                707  ...
# 4  [{'label': 'display', 'lat': 41.89225, 'lng': ...                960  ...
#
#                            location.formattedAddress  \
# 0  [201 W Madison St, Chicago, IL 60606, United S...
# 1  [201 W Madison St (btwn Wells & Franklin St), ...
# 2  [177 N State St (at W. Lake St.), Chicago, IL ...
# 3  [315 S LaSalle St, Chicago, IL 60604, United S...
# 4   [17 E Ohio St, Chicago, IL 60611, United States]
#
#        location.crossStreet delivery.id delivery.url delivery.provider.name  \
# 0                       NaN         NaN          NaN                    NaN
# 1  btwn Wells & Franklin St         NaN          NaN                    NaN
# 2            at W. Lake St.         NaN          NaN                    NaN
# 3                       NaN         NaN          NaN                    NaN
# 4                       NaN         NaN          NaN                    NaN
#
#   delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
#
#   delivery.provider.icon.name venuePage.id location.neighborhood
# 0                         NaN          NaN                   NaN
# 1                         NaN          NaN                   NaN
# 2                         NaN          NaN                   NaN
# 3                         NaN          NaN                   NaN
# 4                         NaN          NaN                   NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                             name          categories           address  \
# 0  Sixty-Five Chinese Restaurant  Chinese Restaurant  201 W Madison St
# 1          65 Chinese Restaurant  Chinese Restaurant  201 W Madison St
# 2    Triple 1 Chinese Restaurant  Chinese Restaurant    177 N State St
# 3          65 Chinese Restaurant  Chinese Restaurant  315 S LaSalle St
# 4     Yu Shan Chinese Restaurant          Restaurant      17 E Ohio St
#
#          lat        lng                                     labeledLatLngs  \
# 0  41.881935 -87.633851  [{'label': 'display', 'lat': 41.881935, 'lng':...
# 1  41.881909 -87.634165  [{'label': 'display', 'lat': 41.88190920166713...
# 2  41.885425 -87.627963  [{'label': 'display', 'lat': 41.88542492566269...
# 3  41.878009 -87.632672  [{'label': 'display', 'lat': 41.87800937208755...
# 4  41.892250 -87.627305  [{'label': 'display', 'lat': 41.89225, 'lng': ...
#
#    distance postalCode  cc     city state        country  \
# 0       458      60606  US  Chicago    IL  United States
# 1       482      60606  US  Chicago    IL  United States
# 2       205      60601  US  Chicago    IL  United States
# 3       707      60604  US  Chicago    IL  United States
# 4       960      60611  US  Chicago    IL  United States
#
#                                     formattedAddress  \
# 0  [201 W Madison St, Chicago, IL 60606, United S...
# 1  [201 W Madison St (btwn Wells & Franklin St), ...
# 2  [177 N State St (at W. Lake St.), Chicago, IL ...
# 3  [315 S LaSalle St, Chicago, IL 60604, United S...
# 4   [17 E Ohio St, Chicago, IL 60611, United States]
#
#                 crossStreet neighborhood                        id
# 0                       NaN          NaN  4f32527d19836c91c7cc560f
# 1  btwn Wells & Franklin St          NaN  4b295853f964a520489d24e3
# 2            at W. Lake St.          NaN  4b65c1ecf964a520c7fd2ae3
# 3                       NaN          NaN  4d0a576d4abf721e2e52c85e
# 4                       NaN          NaN  531af2b7498ef3f61eba1e31

# %%
Crestaurant = dataframe_filtered.head()
Crestaurant
# Out:
#                             name          categories           address  \
# 0  Sixty-Five Chinese Restaurant  Chinese Restaurant  201 W Madison St
# 1          65 Chinese Restaurant  Chinese Restaurant  201 W Madison St
# 2    Triple 1 Chinese Restaurant  Chinese Restaurant    177 N State St
# 3          65 Chinese Restaurant  Chinese Restaurant  315 S LaSalle St
# 4     Yu Shan Chinese Restaurant          Restaurant      17 E Ohio St
#
#          lat        lng                                     labeledLatLngs  \
# 0  41.881935 -87.633851  [{'label': 'display', 'lat': 41.881935, 'lng':...
# 1  41.881909 -87.634165  [{'label': 'display', 'lat': 41.88190920166713...
# 2  41.885425 -87.627963  [{'label': 'display', 'lat': 41.88542492566269...
# 3  41.878009 -87.632672  [{'label': 'display', 'lat': 41.87800937208755...
# 4  41.892250 -87.627305  [{'label': 'display', 'lat': 41.89225, 'lng': ...
#
#    distance postalCode  cc     city state        country  \
# 0       458      60606  US  Chicago    IL  United States
# 1       482      60606  US  Chicago    IL  United States
# 2       205      60601  US  Chicago    IL  United States
# 3       707      60604  US  Chicago    IL  United States
# 4       960      60611  US  Chicago    IL  United States
#
#                                     formattedAddress  \
# 0  [201 W Madison St, Chicago, IL 60606, United S...
# 1  [201 W Madison St (btwn Wells & Franklin St), ...
# 2  [177 N State St (at W. Lake St.), Chicago, IL ...
# 3  [315 S LaSalle St, Chicago, IL 60604, United S...
# 4   [17 E Ohio St, Chicago, IL 60611, United States]
#
#                 crossStreet neighborhood                        id
# 0                       NaN          NaN  4f32527d19836c91c7cc560f
# 1  btwn Wells & Franklin St          NaN  4b295853f964a520489d24e3
# 2            at W. Lake St.          NaN  4b65c1ecf964a520c7fd2ae3
# 3                       NaN          NaN  4d0a576d4abf721e2e52c85e
# 4                       NaN          NaN  531af2b7498ef3f61eba1e31

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Chicago Loop Community area
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Chicago Loop',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Chinese restaurants as blue circle markers
for lat, lng, label in zip(Crestaurant.lat, Crestaurant.lng, Crestaurant.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
venues_map.save('venues_map.html')
